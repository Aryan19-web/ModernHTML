# %%
#Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5
navigation links that are properly placed within the navigation bar using the CSS box model. The navigation
items must change their text color on hover

ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="Rohit.css">
</head>
<def id="more">
    <ins>Home</ins>    <ins>AboutUs</ins>  <ins>Contact</ins>  <ins>Blog</ins>   <ins>Login</ins>

</def>
</html>

CSS CODE

#more{background-color: rgb(118, 118, 247) ; color: white; word-spacing: 40px;height: 100px;font-size: 30px;border: 2px;padding: 0.2em;}


#& Create a div centered with an image and paragraph similar to the image mentioned below.

ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="box.css">
</head>
<body>
    <div>
        <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS4nARyRJ586PBWZ-4laGvBifqMwfPc1363bA&s"  />
    <br>
    <br><b>Course Name:</b>Pw Skills full stack  web development


    </div>
</body>
</html>

CSS CODE

div
{border: 10px rgb(223, 24, 24);padding:10px;margin: 10;background-color: orange;}

#Create a navigation bar similar to question 1. For each navigation item, use a different border style&

ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="jyf.css"
</head>
<body>
    <div id="more">
        <ins id="me">Home</ins>    <ins id="you">AboutUs</ins>  <ins id="yours">Contact</ins>  <ins id="why">Blog</ins>   <ins id="yes">Login</ins>

    </div>
</body>
</html>

CSS CODE:


#more{ color:black; word-spacing: 40px;height: 100px;font-size: 30px;border: 2px solid black;padding: 30px; margin: 20px; text-align: center; background-color: yellow;}
#me{
    margin: 0;
    padding: 0;
    border: 5px solid black;
}

#you{
    margin: 0;
    padding: 0;
    border: 5px solid rgb(36, 160, 205);
}

#yours{
    margin: 0;
    padding: 0;
    border: 5px solid rgb(236, 23, 23);
}

#why{
    margin: 0;
    padding: 0;
    border: 5px solid rgb(36, 227, 71);
}

#yes{
    margin: 0;
    padding: 0;
    border: 5px solid rgb(241, 22, 150);
}

#Create a simple webpage with an image and make the image circular using border-radius.

ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=<device-width>, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="css.css"
</head>
<body>
    <h1>This is a cute dog</h1>

    <p class="dog">
He is white in color<br>
<img class="dog" src="data:image/webp;base64,..."  />

    </p>

    </video>
</body>
</html>

CSS CODE:

.dog{border-radius: 20px;}

#Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font
align center to the page, below the heading have an image of Google fonts and a paragraph about Google
fonts in font “Montserrat” paragraph font style should be“montserrat” font&


ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link  rel="stylesheet" href="style.css">
</head>
<body>
    <h1 id="google"><INS>Google Fonts</INS></h1>
    <br>
    <img id="image" src="data:image/jpeg;base64,..." />
    <br>
    <p id="you">
        Google Fonts is a free, open-source library of fonts offered by Google, providing web designers and developers with access to a wide variety of fonts for use in online projects, according to Lenovo and Wikipedia. The fonts are hosted on Google's servers, making it easy to integrate them into websites without worrying about licensing, as explained by Lenovo and Localo. Google Fonts also includes an interactive web directory and APIs for using the fonts via CSS and Android, according to Wikipedia.
Here's a more detailed breakdown:
Open-Source and Free:
All fonts in Google Fonts are available under open-source licenses, meaning they can be used in both commercial and personal projects without licensing fees, as explained by Google for Developers, and Localo.
Wide Variety:
The library includes a vast collection of fonts, covering various styles and applications, from classic to modern designs, as mentioned by Webflow.
Easy Integration:
Google Fonts offers APIs and web directory for integrating fonts into websites and applications via CSS and Android, according to Wikipedia.
Hosting on Google Servers:
The fonts are hosted on Google's servers, which means they can be used without needing to download and manage the font files locally, as explained by Lenovo.
Developer API:
A dedicated Developer API is available for querying Google Fonts for available font families and styles, according to Google for Developers.
Google Fonts - Wikipedia
Google Fonts (formerly known as Google Web Fonts) is a computer font and web font service owned by Google. This includes free and ...

Wikipedia
Developer API | Google Fonts
22 Jan 2025 — It allows apps to query Google Fonts for the available font families. The REST API supplies data in the JSON format tha...

Google for Developers
Fonts - Google for Developers
All fonts are released under open source licenses. You can use them in any non-commercial or commercial project.

Google for Developers
Show all

    </p>

</body>
</html>


CSS CODE:

#google{font-family: system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Open Sans', 'Helvetica Neue', sans-serif; text-align: center;}
#image{
    border-radius: 20px;;
}
#you{
    font-family: system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Open Sans', 'Helvetica Neue', sans-serif;
}

#Create a simple website as mentioned in the below image.

ANS:

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="PW.CSS">
</head>
<body>
    <h1 id="us">About Us</h1>
    `<p>PW Skills' mission is to permeate through every student/professional's outlook towards jobs and change their attitude and perspective from "How Can I Do It?" to "Of Course I Can Do It". We aim to do this by providing exceptional up skilling courses at affordable rates, while being tech-forward so anyone, anywhere can access and improve their ability to be successful in life.</p>
    <br>
    <img id="pw" src="https://pwskills.com/images/aboutUs/aboutUs.png" />
    <br>
    <h2 id="you">Our Mission</h2>
    <p>PW Skills is the result of a continual effort to exponentially increase the employability of every Indian, irrespective of their socioeconomic status. With accessibility and affordability being the support structure of high-quality, industry-relevant courses, PW Skills aims to empower professionals and students alike to either jumpstart their careers or leverage existing skills with new, future-driven upgrades that will help them realise their full potential.</p>
    <br>
    <img src="https://pwskills.com/images/aboutUs/complete-the-mission.svg" />
    <br>
    <h3 id="we">Our Services</h3>
    <img src="https://pwskills.com/images/aboutUs/service-1.svg" /><B class="hi">Affordable Online courses</B>


</body>
</html>

CSS CODE:

#us{text-align: center;}
#you{text-align: center;}
#we{text-align: center;}
p{text-align: center;}


#Create a simple list of items as mentioned in the below image.

ANS:


<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=<device-width>, initial-scale=1.0">
    <title>Document</title>
    <link rel="stylesheet" href="list.css">
</head>
<body id="hlo">
   <h1><b>Requirenments</b></h1>
   <ol id="hi">
    <li>System with minimum i3 processor or better</li>
    <li>At least 4 GB of Ram</li>
    <li>Working internet connection</li>
    <li>Dedicated to learn</li>
   </ol>
</body>
</html>

CSS CODE:

#hi{list-style-type: lower-roman;}
#hlo{margin: 0;
    padding: 0;
    border: 2px solid black;
}
